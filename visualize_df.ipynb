# %%
import os
import geopandas as gpd
import pandas as pd

# %%
base_dir = os.getcwd()
path = os.path.join(base_dir, 'artifacts', 'shp', 'br_gdf.shp')
path
# Out:
# 'c:\\Users\\guicr\\OneDrive\\Carreira\\Portfolio\\setores_censitarios\\artifacts\\shp\\br_gdf.shp'

# %%
df = gpd.read_file(path)

# %%
df.T
# Out:
#                                                        0       \
# Cod_setor                                     120001305000001
# domicilios                                                282
# renda                                                601805.0
# populacao                                                 957
# ID                                                       23.0
# TIPO                                                   URBANO
# CD_GEOCODB                                                NaN
# NM_BAIRRO                                                 NaN
# CD_GEOCODS                                        12000130500
# NM_SUBDIST                                                NaN
# CD_GEOCODD                                          120001305
# NM_DISTRIT                                         ACRELÂNDIA
# CD_GEOCODM                                            1200013
# NM_MUNICIP                                         ACRELÂNDIA
# ...
