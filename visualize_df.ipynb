# %%
import os
import geopandas as gpd
import pandas as pd

# %%
base_dir = os.getcwd()
path = os.path.join(base_dir, 'artifacts', 'shp', 'br_geo_gdf.shp')
path
# Out:
# 'c:\\Users\\guicr\\OneDrive\\Carreira\\Portfolio\\setores_censitarios\\artifacts\\shp\\br_geo_gdf.shp'

# %%
df = gpd.read_file(path)

# %%
df.T
# Out:
#                                                       0       \
# Cod_setor                                    270010205000001
# geometry   POLYGON ((-37.94455750550959 -9.26638986130343...
#
#                                                       1       \
# Cod_setor                                    270010205000002
# geometry   POLYGON ((-37.939220336062796 -9.2551294519147...
#
#                                                       2       \
# Cod_setor                                    270010205000003
# geometry   POLYGON ((-37.935497053844 -9.26294597227394, ...
#
#                                                       3       \
# Cod_setor                                    270010205000004
# geometry   POLYGON ((-37.9784578138877 -9.274125810994919...
#
#                                                       4       \
# Cod_setor                                    270010205000005
# geometry   POLYGON ((-37.9793072805401 -9.30699177969016,...
#
# ...

# %%
df.to_parquet('./artifacts/test_df.parquet')

# %%
test = gpd.read_parquet('./artifacts/br_geo_gdf.parquet')

# %%
test.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 309246 entries, 0 to 309245
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Cod_setor  309246 non-null  object
#  1   geometry   309246 non-null  geometry
# dtypes: geometry(1), object(1)
# memory usage: 4.7+ MB

# %%
path1 = os.path.join(base_dir, 'artifacts', 'br_data.csv')

# %%
df1 = pd.read_csv(path1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309246 entries, 0 to 309245
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cod_setor            309246 non-null  int64
#  1   domicilios           309246 non-null  int64
#  2   renda                309246 non-null  float64
#  3   Nome_da_UF           309246 non-null  object
#  4   Nome_do_municipio    309246 non-null  object
#  5   Nome_do_distrito     309246 non-null  object
#  6   Nome_do_subdistrito  309246 non-null  object
#  7   Nome_do_bairro       309246 non-null  object
#  8   populacao            309246 non-null  float64
#  9   area_ha              309246 non-null  float64
#  10  densidade            309246 non-null  float64
#  11  renda_dom            309246 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 28.3+ MB

# %%
len(df1['Nome_da_UF '].unique())
# Out:
# 26

# %%
path = 'c:\\Users\\guicr\\OneDrive\\Carreira\\Portfolio\\setores_censitarios\\data\\AC_20231030\\Base informaçoes setores2010 universo AC\\CSV\\Basico_AC.csv'
path1 = 'c:\\Users\\guicr\\OneDrive\\Carreira\\Portfolio\\setores_censitarios\\data\\AC_20231030\\Base informaçoes setores2010 universo AC\\CSV\\Pessoa13_AC.csv'

# %%
def create_df(file):
    df = pd.read_csv(file, encoding='iso-8859-1', sep=';')
    if df.shape[1] < 2:
        df = pd.read_csv(file, encoding='iso-8859-1', sep=',')
    return df

# %%
df = create_df(path)

# %%
df
# Out:
#     Cod_setor  Cod_Grandes Regiões Nome_Grande_Regiao  Cod_UF Nome_da_UF   \
# 0    1,20E+14                    1       Região Norte      12        Acre
# 1    1,20E+14                    1       Região Norte      12        Acre
# 2    1,20E+14                    1       Região Norte      12        Acre
# 3    1,20E+14                    1       Região Norte      12        Acre
# 4    1,20E+14                    1       Região Norte      12        Acre
# ..        ...                  ...                ...     ...         ...
# 869  1,20E+14                    1       Região Norte      12        Acre
# 870  1,20E+14                    1       Região Norte      12        Acre
# 871  1,20E+14                    1       Região Norte      12        Acre
# 872  1,20E+14                    1       Região Norte      12        Acre
# 873  1,20E+14                    1       Região Norte      12        Acre
#
#      Cod_meso  Nome_da_meso  Cod_micro Nome_da_micro  Cod_RM  ...  V003  V004  \
# ...

# %%
df1 = create_df(path1)

# %%
df1
# Out:
#            Cod_setor  Situacao_setor  V001  V002 V003 V004 V005 V006 V007  \
# 0    120001305000001               1   957   957  282  197  210  123   25
# 1    120001305000002               1  1211  1203  344  245  300  161   54
# 2    120001305000003               1  1705  1700  483  347  447  229   46
# 3    120001305000004               5   182   182   53   37   44   22   13
# 4    120001305000005               8   305   305   96   68   77   20   21
# ..               ...             ...   ...   ...  ...  ...  ...  ...  ...
# 869  120080705000017               5   225   225   60   49   70   16    9
# 870  120080705000018               8   410   410  114   86  159   13    2
# 871  120080705000019               5   480   478  135   89  112   64   17
# 872  120080705000020               8   115   115   28   21   42    9    4
# 873  120080705000021               8   734   731  198  147  236   39   19
#
#     V008  ... V126 V127 V128 V129 V130 V131 V132 V133 V134 Unnamed: 136
# ...

# %%
df['Cod_setor'] = df1['Cod_setor']

# %%
df
# Out:
#            Cod_setor  Cod_Grandes Regiões Nome_Grande_Regiao  Cod_UF  \
# 0    120001305000001                    1       Região Norte      12
# 1    120001305000002                    1       Região Norte      12
# 2    120001305000003                    1       Região Norte      12
# 3    120001305000004                    1       Região Norte      12
# 4    120001305000005                    1       Região Norte      12
# ..               ...                  ...                ...     ...
# 869  120080705000017                    1       Região Norte      12
# 870  120080705000018                    1       Região Norte      12
# 871  120080705000019                    1       Região Norte      12
# 872  120080705000020                    1       Região Norte      12
# 873  120080705000021                    1       Região Norte      12
#
#     Nome_da_UF   Cod_meso  Nome_da_meso  Cod_micro Nome_da_micro  Cod_RM  ...  \
# ...

# %%
df.to_csv(path, sep=',', encoding='iso-8859-1', index=False)
